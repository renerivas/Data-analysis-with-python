# %% [markdown]
# # **1. Limpieza de datos**

# %% [markdown]
# ## 1.1 Importando datos a Python
# **Importando librerias**
#
# Las librerias más utilizadas para Ciencia de Datos son:

# %%
# Importando librerias
import pandas as pd
import os
import math as mt
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn
import statistics
from scipy import stats

# %% [markdown]
# **Importando datos desde Excel**
#
# Para importar datos a Python desde un libro de Microsoft Excel, se utiliza la función **read_excel** de **pandas**. Su sintaxis es la siguiente:
# *nombre_dataframe = pd.read_excel("ruta//nombrearchivo", sheet_name = "nombre_hoja")*

# %%
data_banco= pd.read_excel('Data_Banco_v2.xlsx', sheet_name='Data')
data_banco.head(5)
# Out:
#    Sucursal  Cajero  ID_Transaccion Transaccion Entidad_Bancaria  \
# 0        62    4820               2  Cobro/Pago    Internacional
# 1        62    4820               2  Cobro/Pago         Nacional
# 2        62    4820               2  Cobro/Pago         Nacional
# 3        62    4820               2  Cobro/Pago         Nacional
# 4        62    4820               2  Cobro/Pago         Nacional
#
#    Tiempo_Servicio_seg Satisfaccion    Monto  Interes
# 0                311.0    Muy Bueno   2889,3   335.97
# 1                156.0         Malo  1670,69   137.23
# 2                248.0      Regular  3172,49   143.30
# 3                 99.0      Regular  1764.92    42.55
# 4                123.0    Muy Bueno  1835.69   199.47

# %%
data_banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24299 entries, 0 to 24298
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sucursal             24299 non-null  int64
#  1   Cajero               24299 non-null  int64
#  2   ID_Transaccion       24299 non-null  int64
#  3   Transaccion          24299 non-null  object
#  4   Entidad_Bancaria     24299 non-null  object
#  5   Tiempo_Servicio_seg  24299 non-null  float64
#  6   Satisfaccion         24299 non-null  object
#  7   Monto                24299 non-null  object
#  8   Interes              24299 non-null  float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 1.7+ MB

# %%
data_sucursal= pd.read_excel('Data_Banco_v2.xlsx', sheet_name='Data_Sucursal')
data_sucursal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID_Sucursal    5 non-null      int64
#  1   Sucursal       5 non-null      object
#  2   Nuevo_Sistema  5 non-null      object
#  3   Plataforma     5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
data_cajero= pd.read_excel('Data_Banco_v2.xlsx', sheet_name='Data_Cajero')
data_cajero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Cajero           27 non-null     int64
#  1   Edad             27 non-null     int64
#  2   Sexo             27 non-null     object
#  3   Nivel_Formacion  27 non-null     object
#  4   Ingreso          27 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.2+ KB

# %%
data_banco.isna().sum()
# Out:
# Sucursal               0
# Cajero                 0
# ID_Transaccion         0
# Transaccion            0
# Entidad_Bancaria       0
# Tiempo_Servicio_seg    0
# Satisfaccion           0
# Monto                  0
# Interes                0
# dtype: int64

# %%
data_banco.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24294    False
# 24295    False
# 24296    False
# 24297    False
# 24298    False
# Length: 24299, dtype: bool

# %% [markdown]
# ## 1.2. Entendiendo los datos
# Para entender los datos que tenemos disponibles, podemos:
# *   Acceder a los primeros elementos de cada dataframe, con el metodo de lista .*head()*
#
# *nombre_dataframe.head()*
# *   A través de una tabla resumen con el método *.info()*
#
# *data_banco.info()*

# %%
# Correcion de variables numerica
data_banco['Monto'] = pd.to_numeric(data_banco['Monto'].replace(',','.',regex = True))
data_banco.head(5)
data_banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24299 entries, 0 to 24298
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sucursal             24299 non-null  int64
#  1   Cajero               24299 non-null  int64
#  2   ID_Transaccion       24299 non-null  int64
#  3   Transaccion          24299 non-null  object
#  4   Entidad_Bancaria     24299 non-null  object
#  5   Tiempo_Servicio_seg  24299 non-null  float64
#  6   Satisfaccion         24299 non-null  object
#  7   Monto                24299 non-null  float64
#  8   Interes              24299 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# ## 1.3 Transformación de tipos datos
# Ejecutaremos las recomendaciones con tipos de datos:
# *   Transformación a *string*
# *   Validación de datos númericos
# *   Validación de datos fecha y/o categoricos

# %%
data_banco['Satisfaccion'].unique()
# Out:
# array(['Muy Bueno', 'Malo', 'Regular', 'Bueno', 'Muy Malo'], dtype=object)

# %%
# Categoricas (nominales y ordinales)
data_banco['Satisfaccion'] = pd.Categorical(data_banco['Satisfaccion'],
               categories = ['Muy Malo', 'Malo', 'Regular', 'Bueno', 'Muy Bueno'],
               ordered = True)
data_banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24299 entries, 0 to 24298
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sucursal             24299 non-null  int64
#  1   Cajero               24299 non-null  int64
#  2   ID_Transaccion       24299 non-null  int64
#  3   Transaccion          24299 non-null  object
#  4   Entidad_Bancaria     24299 non-null  object
#  5   Tiempo_Servicio_seg  24299 non-null  float64
#  6   Satisfaccion         24299 non-null  category
#  7   Monto                24299 non-null  float64
#  8   Interes              24299 non-null  float64
# dtypes: category(1), float64(3), int64(3), object(2)
# memory usage: 1.5+ MB

# %%
data_banco ['Entidad_Bancaria'] = pd.Categorical(data_banco['Entidad_Bancaria'],
  categories = ['Nacional', 'Internacional'],
  ordered = False)
data_banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24299 entries, 0 to 24298
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sucursal             24299 non-null  int64
#  1   Cajero               24299 non-null  int64
#  2   ID_Transaccion       24299 non-null  int64
#  3   Transaccion          24299 non-null  object
#  4   Entidad_Bancaria     24299 non-null  category
#  5   Tiempo_Servicio_seg  24299 non-null  float64
#  6   Satisfaccion         24299 non-null  category
#  7   Monto                24299 non-null  float64
#  8   Interes              24299 non-null  float64
# dtypes: category(2), float64(3), int64(3), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# # **2. Creación de nuevas variables**
# 1.   Crear las variable Monto_total = Monto + Interes
# 2.   Crear la variable Tiempo_Servicio_min

# %%
# Monto Total (calculo directo)
data_banco['Monto_total'] = data_banco['Monto'] + data_banco ['Interes']
data_banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24299 entries, 0 to 24298
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sucursal             24299 non-null  int64
#  1   Cajero               24299 non-null  int64
#  2   ID_Transaccion       24299 non-null  int64
#  3   Transaccion          24299 non-null  object
#  4   Entidad_Bancaria     24299 non-null  category
#  5   Tiempo_Servicio_seg  24299 non-null  float64
#  6   Satisfaccion         24299 non-null  category
#  7   Monto                24299 non-null  float64
#  8   Interes              24299 non-null  float64
#  9   Monto_total          24299 non-null  float64
# dtypes: category(2), float64(4), int64(3), object(1)
# memory usage: 1.5+ MB

# %%
#Monto_total = data_banco['Monto'] + data_banco ['Interes']
#data_banco['Monto_total_2'] = Monto_total

# %%
#  Tiempo_servicio_min
# dataframe = dataframe.assign(Nueva_columna = función_lambda)
# lambda parametros: calculo_parametros
# lambda dataframe: calculo_dataframe_columnas
data_banco = data_banco.assign(Tiempo_Servicio_min = lambda df : df['Tiempo_Servicio_seg']/60)

# %%
data_banco['Tiempo_Servicio_min_2']=data_banco['Tiempo_Servicio_seg']/60
data_banco.head(5)
# Out:
#    Sucursal  Cajero  ID_Transaccion Transaccion Entidad_Bancaria  \
# 0        62    4820               2  Cobro/Pago    Internacional
# 1        62    4820               2  Cobro/Pago         Nacional
# 2        62    4820               2  Cobro/Pago         Nacional
# 3        62    4820               2  Cobro/Pago         Nacional
# 4        62    4820               2  Cobro/Pago         Nacional
#
#    Tiempo_Servicio_seg Satisfaccion    Monto  Interes  Monto_total  \
# 0                311.0    Muy Bueno  2889.30   335.97      3225.27
# 1                156.0         Malo  1670.69   137.23      1807.92
# 2                248.0      Regular  3172.49   143.30      3315.79
# 3                 99.0      Regular  1764.92    42.55      1807.47
# 4                123.0    Muy Bueno  1835.69   199.47      2035.16
#
#    Tiempo_Servicio_min  Tiempo_Servicio_min_2
# 0             5.183333               5.183333
# 1             2.600000               2.600000
# 2             4.133333               4.133333
# 3             1.650000               1.650000
# 4             2.050000               2.050000

# %% [markdown]
# # **3. Estadística descriptiva**

# %% [markdown]
# ## 3.1 Medidas de tendencia central

# %%
# Promedio
data_banco['Tiempo_Servicio_min'].mean()
# Out:
# 2.5929998872252464

# %%
# Mediana (2.040871505892167)
data_banco['Tiempo_Servicio_min'].median()
# Out:
# 2.040871505892167

# %% [markdown]
# ## 3.2 Medidas de posicion

# %%
# Minimo
data_banco['Tiempo_Servicio_min'].min()
# Out:
# 0.302196172877495

# %%
# Minimo
data_banco['Tiempo_Servicio_min'].max()
# Out:
# 26.7116386425825

# %%
# Cuartiles
# dataframe[columna].quantile(np.arange(0, 1.25, 0.25))
data_banco['Tiempo_Servicio_min'].quantile(np.arange(0, 1.25, 0.25))
# Out:
# 0.00     0.302196
# 0.25     1.261520
# 0.50     2.040872
# 0.75     3.295508
# 1.00    26.711639
# Name: Tiempo_Servicio_min, dtype: float64

# %% [markdown]
# ## 3.3 Medidas de dispersion

# %%
data_banco['Tiempo_Servicio_min'].var()
# Out:
# 4.0006305210855775

# %%
data_banco['Tiempo_Servicio_min'].std()
# Out:
# 2.0001576240600585

# %% [markdown]
# ## 3.4 Resumen en Python

# %%
data_banco['Tiempo_Servicio_min'].describe()
# Out:
# count    24299.000000
# mean         2.593000
# std          2.000158
# min          0.302196
# 25%          1.261520
# 50%          2.040872
# 75%          3.295508
# max         26.711639
# Name: Tiempo_Servicio_min, dtype: float64

# %%
#para todas las columnas
data_banco.describe()
# Out:
#            Sucursal        Cajero  ID_Transaccion  Tiempo_Servicio_seg  \
# count  24299.000000  24299.000000    24299.000000         24299.000000
# mean     208.112968   2918.810774        4.433968           155.579993
# std      176.493661   1755.399031        2.995200           120.009457
# min       62.000000     56.000000        2.000000            18.131770
# 25%       85.000000    472.000000        3.000000            75.691187
# 50%       85.000000   3678.000000        3.000000           122.452290
# 75%      443.000000   3983.000000        3.000000           197.730457
# max      586.000000   5286.000000       10.000000          1602.698319
#
#               Monto       Interes   Monto_total  Tiempo_Servicio_min  \
# count  24299.000000  24299.000000  24299.000000         24299.000000
# mean    1996.156149     86.404638   2082.560786             2.593000
# std      816.146998     99.591424    856.154931             2.000158
# min       53.820000      0.000000     59.710000             0.302196
# 25%     1417.730000      0.000000   1476.030000             1.261520
# 50%     2087.430000     50.110000   2172.790000             2.040872
# 75%     2482.090000    147.425000   2592.235000             3.295508
# max     6278.020000    756.920000   6632.720000            26.711639
#
#        Tiempo_Servicio_min_2
# count           24299.000000
# mean                2.593000
# std                 2.000158
# min                 0.302196
# 25%                 1.261520
# 50%                 2.040872
# 75%                 3.295508
# max                26.711639

# %% [markdown]
# # **4. Tablas resumen**

# %% [markdown]
# ## 4.1 Resumen de estadísticas

# %%
# data_frame[lista variables estadísticas + variables agrupamiento].groupby(lista variables agrupamiento).metodo

data_banco[['Satisfaccion','Tiempo_Servicio_seg']].groupby('Satisfaccion').mean()
# Out:
#               Tiempo_Servicio_seg
# Satisfaccion
# Muy Malo               138.094382
# Malo                   144.352672
# Regular                157.659044
# Bueno                  161.619952
# Muy Bueno              164.758238

# %%
data_banco.groupby('Satisfaccion').describe()
# Out:
#              Sucursal                                                          \
#                 count        mean         std   min   25%   50%    75%    max
# Satisfaccion
# Muy Malo       3009.0  224.932868  184.443997  62.0  85.0  85.0  443.0  586.0
# Malo           4474.0  212.907689  175.071826  62.0  85.0  85.0  267.0  586.0
# Regular        4639.0  208.380685  175.588990  62.0  85.0  85.0  443.0  586.0
# Bueno          5915.0  199.975486  172.646539  62.0  85.0  85.0  267.0  586.0
# Muy Bueno      6262.0  204.093261  177.262283  62.0  85.0  85.0  443.0  586.0
#
#               Cajero               ... Tiempo_Servicio_min             \
#                count         mean  ...                 75%        max
# Satisfaccion                       ...
# Muy Malo      3009.0  2909.480891  ...            2.938995  13.721921
# Malo          4474.0  2909.793920  ...            3.062627  22.276138
# Regular       4639.0  2917.800604  ...            3.341692  15.503570
# Bueno         5915.0  2951.393238  ...            3.413680  20.800597
# Muy Bueno     6262.0  2899.707601  ...            3.509022  26.711639
#
#              Tiempo_Servicio_min_2                                          \
#                              count      mean       std       min       25%
# Satisfaccion
# Muy Malo                    3009.0  2.301573  1.702266  0.302490  1.159079
# Malo                        4474.0  2.405878  1.825518  0.333333  1.195739
# Regular                     4639.0  2.627651  2.009998  0.333333  1.283333
# Bueno                       5915.0  2.693666  2.099949  0.316781  1.288512
# Muy Bueno                   6262.0  2.745971  2.120134  0.302196  1.330326
#
#
#                    50%       75%        max
# Satisfaccion
# Muy Malo      1.850000  2.938995  13.721921
# Malo          1.923507  3.062627  22.276138
# Regular       2.056655  3.341692  15.503570
# Bueno         2.104748  3.413680  20.800597
# Muy Bueno     2.137101  3.509022  26.711639
#
# [5 rows x 72 columns]

# %% [markdown]
# ## 4.2 Tablas de frecuencias

# %%
data_banco[['Satisfaccion','Entidad_Bancaria','Tiempo_Servicio_seg', 'Monto_total']].groupby(['Satisfaccion','Entidad_Bancaria']).describe()
# Out:
#                               Tiempo_Servicio_seg                          \
#                                             count        mean         std
# Satisfaccion Entidad_Bancaria
# Muy Malo     Nacional                      2562.0  137.798329  101.276232
#              Internacional                  447.0  139.791224  107.032346
# Malo         Nacional                      3840.0  144.071278  109.448714
#              Internacional                  634.0  146.057012  110.100079
# Regular      Nacional                      3974.0  157.943961  121.021344
#              Internacional                  665.0  155.956394  118.125051
# Bueno        Nacional                      5052.0  161.755885  125.643235
#              Internacional                  863.0  160.824201  128.118946
# Muy Bueno    Nacional                      5364.0  164.733128  126.579587
#              Internacional                  898.0  164.908228  130.971216
#
#                                                                              \
#                                      min        25%         50%         75%
# Satisfaccion Entidad_Bancaria
# Muy Malo     Nacional          20.000000  70.000000  112.026396  175.879810
#              Internacional     18.149392  66.779243  108.203744  178.919602
# Malo         Nacional          20.000000  71.136946  115.251455  183.775240
#              Internacional     22.000000  73.295833  117.380454  180.859295
# Regular      Nacional          20.000000  77.000000  123.637468  200.519707
#              Internacional     20.000000  77.000000  121.648149  200.047365
# Bueno        Nacional          19.006876  78.556383  126.264829  204.384199
#              Internacional     20.000000  71.283859  126.418729  209.430861
# Muy Bueno    Nacional          18.131770  80.809364  128.699744  211.369865
#              Internacional     21.016823  76.018970  125.568178  206.159985
#
#                                            Monto_total               \
#                                        max       count         mean
# Satisfaccion Entidad_Bancaria
# Muy Malo     Nacional           823.315231      2562.0  2045.868833
#              Internacional      647.732891       447.0  2021.013982
# Malo         Nacional          1336.568307      3840.0  2044.195422
#              Internacional      858.797733       634.0  2061.044763
# Regular      Nacional           930.214187      3974.0  2072.724887
#              Internacional      907.700386       665.0  2104.646526
# Bueno        Nacional          1248.035801      5052.0  2103.611625
#              Internacional     1060.395312       863.0  2138.000243
# Muy Bueno    Nacional          1602.698319      5364.0  2106.083967
#              Internacional      947.596243       898.0  2112.081704
#
#                                                                         \
#                                       std     min        25%       50%
# Satisfaccion Entidad_Bancaria
# Muy Malo     Nacional          824.077783  114.04  1460.5250  2132.305
#              Internacional     814.110237  250.10  1452.9300  2144.460
# Malo         Nacional          850.339064  104.33  1433.4625  2143.340
#              Internacional     860.746307  149.66  1438.0300  2114.640
# Regular      Nacional          865.924109   59.71  1452.2300  2168.105
#              Internacional     853.354254  199.60  1517.4100  2193.000
# Bueno        Nacional          866.515034   64.37  1485.8850  2202.090
#              Internacional     893.293968   95.98  1494.3200  2183.220
# Muy Bueno    Nacional          856.339010   88.87  1514.3750  2187.580
#              Internacional     841.125352  134.19  1546.7775  2199.280
#
#
#                                      75%      max
# Satisfaccion Entidad_Bancaria
# Muy Malo     Nacional          2566.2600  6168.01
#              Internacional     2472.7300  4730.47
# Malo         Nacional          2553.9650  6287.65
#              Internacional     2550.2525  5659.76
# Regular      Nacional          2591.6850  6044.42
#              Internacional     2615.7400  6090.35
# Bueno        Nacional          2622.4250  6632.72
#              Internacional     2641.2800  5763.46
# Muy Bueno    Nacional          2610.4000  6420.75
#              Internacional     2632.2625  5540.65

# %%
data_banco[['Satisfaccion','Entidad_Bancaria','Tiempo_Servicio_seg', 'Monto_total']].groupby(['Satisfaccion','Entidad_Bancaria']).describe().reset_index()
# Out:
#   Satisfaccion Entidad_Bancaria Tiempo_Servicio_seg                          \
#                                               count        mean         std
# 0     Muy Malo         Nacional              2562.0  137.798329  101.276232
# 1     Muy Malo    Internacional               447.0  139.791224  107.032346
# 2         Malo         Nacional              3840.0  144.071278  109.448714
# 3         Malo    Internacional               634.0  146.057012  110.100079
# 4      Regular         Nacional              3974.0  157.943961  121.021344
# 5      Regular    Internacional               665.0  155.956394  118.125051
# 6        Bueno         Nacional              5052.0  161.755885  125.643235
# 7        Bueno    Internacional               863.0  160.824201  128.118946
# 8    Muy Bueno         Nacional              5364.0  164.733128  126.579587
# 9    Muy Bueno    Internacional               898.0  164.908228  130.971216
#
#                                                              Monto_total  \
#          min        25%         50%         75%          max       count
# 0  20.000000  70.000000  112.026396  175.879810   823.315231      2562.0
# 1  18.149392  66.779243  108.203744  178.919602   647.732891       447.0
# 2  20.000000  71.136946  115.251455  183.775240  1336.568307      3840.0
# 3  22.000000  73.295833  117.380454  180.859295   858.797733       634.0
# 4  20.000000  77.000000  123.637468  200.519707   930.214187      3974.0
# 5  20.000000  77.000000  121.648149  200.047365   907.700386       665.0
# 6  19.006876  78.556383  126.264829  204.384199  1248.035801      5052.0
# 7  20.000000  71.283859  126.418729  209.430861  1060.395312       863.0
# 8  18.131770  80.809364  128.699744  211.369865  1602.698319      5364.0
# 9  21.016823  76.018970  125.568178  206.159985   947.596243       898.0
#
#
#           mean         std     min        25%       50%        75%      max
# 0  2045.868833  824.077783  114.04  1460.5250  2132.305  2566.2600  6168.01
# 1  2021.013982  814.110237  250.10  1452.9300  2144.460  2472.7300  4730.47
# 2  2044.195422  850.339064  104.33  1433.4625  2143.340  2553.9650  6287.65
# 3  2061.044763  860.746307  149.66  1438.0300  2114.640  2550.2525  5659.76
# 4  2072.724887  865.924109   59.71  1452.2300  2168.105  2591.6850  6044.42
# 5  2104.646526  853.354254  199.60  1517.4100  2193.000  2615.7400  6090.35
# 6  2103.611625  866.515034   64.37  1485.8850  2202.090  2622.4250  6632.72
# 7  2138.000243  893.293968   95.98  1494.3200  2183.220  2641.2800  5763.46
# 8  2106.083967  856.339010   88.87  1514.3750  2187.580  2610.4000  6420.75
# 9  2112.081704  841.125352  134.19  1546.7775  2199.280  2632.2625  5540.65

# %%
data_banco[['Entidad_Bancaria','Satisfaccion']].value_counts()
# Out:
# Entidad_Bancaria  Satisfaccion
# Nacional          Muy Bueno       5364
#                   Bueno           5052
#                   Regular         3974
#                   Malo            3840
#                   Muy Malo        2562
# Internacional     Muy Bueno        898
#                   Bueno            863
#                   Regular          665
#                   Malo             634
#                   Muy Malo         447
# dtype: int64

# %%
# Crosstab
pd.crosstab(index = data_banco['Entidad_Bancaria'],
            columns = data_banco['Satisfaccion'],
            normalize = 'all')*100
# Out:
# Satisfaccion       Muy Malo       Malo    Regular      Bueno  Muy Bueno
# Entidad_Bancaria
# Nacional          10.543644  15.803119  16.354582  20.790979  22.074983
# Internacional      1.839582   2.609161   2.736738   3.551586   3.695625

# %%
pd.crosstab(index = [data_banco['Entidad_Bancaria'], data_banco['Transaccion']],
            columns = [data_banco['Satisfaccion'], data_banco['Sucursal']],
            normalize = 'all')*100
# Out:
# Satisfaccion                       Muy Malo                                \
# Sucursal                                62        85        267       443
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.283962  0.539117  0.493847  0.271616
#                  Cobro/Pago        0.197539  0.201654  0.230462  0.098769
#                  Deposito          1.004157  3.654471  1.164657  1.185234
# Internacional    Cambio de cheque  0.065846  0.094654  0.098769  0.045269
#                  Cobro/Pago        0.024692  0.041154  0.057616  0.053500
#                  Deposito          0.197539  0.584386  0.172847  0.242808
#
# Satisfaccion                                     Malo                      \
# Sucursal                                586       62        85        267
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.168731  0.444463  0.983580  0.995926
#                  Cobro/Pago        0.069962  0.279847  0.485617  0.333347
#                  Deposito          0.979464  1.407465  5.543438  1.625581
# Internacional    Cambio de cheque  0.016462  0.057616  0.189308  0.144039
#                  Cobro/Pago        0.004115  0.049385  0.102885  0.094654
#                  Deposito          0.139923  0.246924  0.794271  0.296308
#
# Satisfaccion                                           ...     Bueno  \
# Sucursal                                443       586  ...       62
# Entidad_Bancaria Transaccion                           ...
# Nacional         Cambio de cheque  0.333347  0.234578  ...  0.703733
#                  Cobro/Pago        0.193424  0.078193  ...  0.362155
#                  Deposito          1.851928  1.012387  ...  1.341619
# Internacional    Cambio de cheque  0.057616  0.016462  ...  0.082308
#                  Cobro/Pago        0.028808  0.012346  ...  0.061731
#                  Deposito          0.304539  0.214001  ...  0.263385
#
# Satisfaccion                                                               \
# Sucursal                                85        267       443       586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2.020659  0.884810  1.070003  0.349809
#                  Cobro/Pago        1.563850  0.345693  0.604963  0.098769
#                  Deposito          7.226635  1.316927  2.008313  0.893041
# Internacional    Cambio de cheque  0.366270  0.139923  0.172847  0.065846
#                  Cobro/Pago        0.308655  0.049385  0.086423  0.020577
#                  Deposito          1.246965  0.172847  0.353924  0.160500
#
# Satisfaccion                      Muy Bueno                                \
# Sucursal                                62        85        267       443
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.596732  2.316968  0.843656  1.522696
#                  Cobro/Pago        0.321001  1.814890  0.333347  0.732540
#                  Deposito          1.131734  7.979752  0.925964  2.016544
# Internacional    Cambio de cheque  0.107000  0.312770  0.111116  0.218116
#                  Cobro/Pago        0.061731  0.308655  0.078193  0.107000
#                  Deposito          0.246924  1.382773  0.148154  0.296308
#
# Satisfaccion
# Sucursal                                586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.432117
#                  Cobro/Pago        0.152270
#                  Deposito          0.954772
# Internacional    Cambio de cheque  0.094654
#                  Cobro/Pago        0.028808
#                  Deposito          0.193424
#
# [6 rows x 25 columns]

# %%
pd.crosstab(index = [data_banco['Entidad_Bancaria'], data_banco['Transaccion']],
            columns = [data_banco['Satisfaccion'], data_banco['Sucursal'], data_banco['Cajero']],
            normalize = 'all')*100
# Out:
# Satisfaccion                       Muy Malo                                \
# Sucursal                                62
# Cajero                                 4820      5174      5211      5286
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.107000  0.004115  0.057616  0.115231
#                  Cobro/Pago        0.061731  0.004115  0.053500  0.078193
#                  Deposito          0.353924  0.037039  0.300424  0.312770
# Internacional    Cambio de cheque  0.032923  0.000000  0.024692  0.008231
#                  Cobro/Pago        0.012346  0.000000  0.004115  0.008231
#                  Deposito          0.086423  0.012346  0.057616  0.041154
#
# Satisfaccion                                                               \
# Sucursal                                85
# Cajero                                 70        357       472       3678
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.032923  0.107000  0.156385  0.098769
#                  Cobro/Pago        0.024692  0.028808  0.069962  0.032923
#                  Deposito          0.201654  0.584386  0.893041  0.736656
# Internacional    Cambio de cheque  0.004115  0.016462  0.057616  0.004115
#                  Cobro/Pago        0.000000  0.008231  0.020577  0.000000
#                  Deposito          0.024692  0.115231  0.111116  0.123462
#
# Satisfaccion                                           ... Muy Bueno  \
# Sucursal                                               ...       443
# Cajero                                 3983      4837  ...      4208
# Entidad_Bancaria Transaccion                           ...
# Nacional         Cambio de cheque  0.090539  0.053500  ...  0.637886
#                  Cobro/Pago        0.028808  0.016462  ...  0.300424
#                  Deposito          1.049426  0.189308  ...  0.695502
# Internacional    Cambio de cheque  0.008231  0.004115  ...  0.090539
#                  Cobro/Pago        0.008231  0.004115  ...  0.032923
#                  Deposito          0.160500  0.049385  ...  0.098769
#
# Satisfaccion                                                               \
# Sucursal                                586
# Cajero                                 56        63        87        299
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.160500  0.000000  0.004115  0.176962
#                  Cobro/Pago        0.078193  0.008231  0.000000  0.041154
#                  Deposito          0.325116  0.028808  0.008231  0.378616
# Internacional    Cambio de cheque  0.032923  0.004115  0.000000  0.032923
#                  Cobro/Pago        0.020577  0.000000  0.000000  0.008231
#                  Deposito          0.057616  0.000000  0.004115  0.107000
#
# Satisfaccion                                                               \
# Sucursal
# Cajero                                 2623      3023      3327      4353
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.020577  0.016462  0.020577  0.008231
#                  Cobro/Pago        0.004115  0.012346  0.000000  0.004115
#                  Deposito          0.098769  0.045269  0.008231  0.004115
# Internacional    Cambio de cheque  0.008231  0.004115  0.004115  0.000000
#                  Cobro/Pago        0.000000  0.000000  0.000000  0.000000
#                  Deposito          0.012346  0.000000  0.000000  0.000000
#
# Satisfaccion
# Sucursal
# Cajero                                 4424
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  0.024692
#                  Cobro/Pago        0.004115
#                  Deposito          0.057616
# Internacional    Cambio de cheque  0.008231
#                  Cobro/Pago        0.000000
#                  Deposito          0.012346
#
# [6 rows x 130 columns]

# %%
pd.crosstab(index = data_banco['Entidad_Bancaria'],
            columns = data_banco['Satisfaccion'],
            values = data_banco['Monto_total'],
            aggfunc = ('min','max'))
# Out:
#                       max                                           min  \
# Satisfaccion     Muy Malo     Malo  Regular    Bueno Muy Bueno Muy Malo
# Entidad_Bancaria
# Nacional          6168.01  6287.65  6044.42  6632.72   6420.75   114.04
# Internacional     4730.47  5659.76  6090.35  5763.46   5540.65   250.10
#
#
# Satisfaccion        Malo Regular  Bueno Muy Bueno
# Entidad_Bancaria
# Nacional          104.33   59.71  64.37     88.87
# Internacional     149.66  199.60  95.98    134.19

# %%
pd.crosstab(index = [data_banco['Entidad_Bancaria'], data_banco['Transaccion']],
            columns = [data_banco['Satisfaccion'], data_banco['Sucursal']],
            values = data_banco['Monto_total'],
            aggfunc = ('min','max','std'))
# Out:
#                                        max                             \
# Satisfaccion                      Muy Malo
# Sucursal                               62       85       267      443
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  3541.52  5170.97  5203.70  4323.11
#                  Cobro/Pago        3774.48  5010.33  6168.01  4078.59
#                  Deposito          3628.10  4877.87  4666.78  4064.20
# Internacional    Cambio de cheque  2743.16  4172.49  4489.88  4303.85
#                  Cobro/Pago        2340.93  4730.47  4202.01  3345.90
#                  Deposito          3659.59  3924.85  4424.05  3875.83
#
#                                                                        \
# Satisfaccion                                   Malo
# Sucursal                               586      62       85       267
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  3351.01  3673.49  4220.48  4877.58
#                  Cobro/Pago        4085.79  3633.00  5394.94  5903.72
#                  Deposito          3804.37  3369.86  6287.65  4337.98
# Internacional    Cambio de cheque  3070.31  3354.14  3853.55  4161.96
#                  Cobro/Pago        1461.78  3240.33  4291.53  4411.27
#                  Deposito          3181.06  3077.51  5659.76  4251.26
#
#                                                      ...          std  \
# Satisfaccion                                         ...        Bueno
# Sucursal                               443      586  ...          62
# Entidad_Bancaria Transaccion                         ...
# Nacional         Cambio de cheque  4472.59  3165.95  ...   754.408329
#                  Cobro/Pago        6278.98  4878.16  ...   913.439056
#                  Deposito          5070.34  3657.51  ...   699.139260
# Internacional    Cambio de cheque  3501.57  3061.64  ...   683.636571
#                  Cobro/Pago        3756.15  2792.61  ...  1117.092798
#                  Deposito          4681.38  3000.02  ...   672.645614
#
#                                                                          \
# Satisfaccion
# Sucursal                                   85          267          443
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque   859.589707  806.769993   761.041294
#                  Cobro/Pago         931.131984  905.541838  1013.261870
#                  Deposito           821.543042  842.015411   797.184955
# Internacional    Cambio de cheque   756.512399  813.332766   765.763904
#                  Cobro/Pago        1060.081102  842.412457  1382.063625
#                  Deposito           846.744640  905.434993   832.446288
#
#                                                                        \
# Satisfaccion                                    Muy Bueno
# Sucursal                                  586         62          85
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  807.628056  689.170953  835.656598
#                  Cobro/Pago        648.171313  706.034321  965.495709
#                  Deposito          690.108107  687.729524  795.696282
# Internacional    Cambio de cheque  746.785866  716.496760  803.460504
#                  Cobro/Pago        487.969026  689.085980  873.406329
#                  Deposito          696.191317  723.359460  793.916482
#
#
# Satisfaccion
# Sucursal                                  267          443         586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  825.662049   924.837577  683.058178
#                  Cobro/Pago        890.576169  1014.143722  805.483312
#                  Deposito          804.979969   812.750379  753.188298
# Internacional    Cambio de cheque  933.251384   915.765024  737.211725
#                  Cobro/Pago        840.504958   997.600985  511.123945
#                  Deposito          827.326044   809.157366  737.097962
#
# [6 rows x 75 columns]

# %%
pd.crosstab(index = [data_banco['Entidad_Bancaria'], data_banco['Transaccion']],
            columns = [data_banco['Satisfaccion'], data_banco['Sucursal']],
            values = data_banco['Monto_total'],
            aggfunc = ('mean'))
# Out:
# Satisfaccion                          Muy Malo                            \
# Sucursal                                   62           85           267
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2024.870870  2250.053817  2268.751833
#                  Cobro/Pago        2046.653125  2842.692449  2727.502857
#                  Deposito          1812.322664  2050.882601  1997.838304
# Internacional    Cambio de cheque  1589.861875  2385.933478  2070.034167
#                  Cobro/Pago        2012.905000  2834.870000  2452.595000
#                  Deposito          1772.318958  2034.199859  2102.794286
#
# Satisfaccion                                                        Malo  \
# Sucursal                                   443          586          62
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2320.939545  1880.921220  2007.889074
#                  Cobro/Pago        2207.568750  2146.262353  2085.866912
#                  Deposito          1968.569757  1802.632143  1699.360205
# Internacional    Cambio de cheque  2274.514545  1702.435000  2183.645714
#                  Cobro/Pago        2289.489231  1461.780000  2160.758333
#                  Deposito          1997.837966  1631.284706  1770.014500
#
# Satisfaccion                                                              \
# Sucursal                                   85           267          443
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2234.251757  2191.300331  2236.700370
#                  Cobro/Pago        2669.200085  2631.321975  2956.595106
#                  Deposito          2048.811403  1982.536709  2011.029267
# Internacional    Cambio de cheque  2017.801087  2504.664857  2091.245714
#                  Cobro/Pago        2735.820800  2498.276522  2343.275714
#                  Deposito          2001.742694  2005.566250  1986.784054
#
# Satisfaccion                                    ...        Bueno               \
# Sucursal                                   586  ...          62           85
# Entidad_Bancaria Transaccion                    ...
# Nacional         Cambio de cheque  1847.927368  ...  1809.614035  2328.502648
#                  Cobro/Pago        2150.663684  ...  2092.098636  2689.196237
#                  Deposito          1639.485447  ...  1712.924785  2013.957278
# Internacional    Cambio de cheque  2571.730000  ...  2068.782000  2128.086180
#                  Cobro/Pago        2555.476667  ...  2236.307333  2693.585867
#                  Deposito          1851.356154  ...  1723.520156  2087.520924
#
# Satisfaccion                                                              \
# Sucursal                                   267          443          586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2218.217767  2214.471077  1826.343412
#                  Cobro/Pago        2656.291071  2789.243265  2094.453750
#                  Deposito          1950.198719  1998.891885  1764.654378
# Internacional    Cambio de cheque  2271.415882  2117.297143  1831.948750
#                  Cobro/Pago        3258.440000  2662.936667  1937.088000
#                  Deposito          2163.333333  2134.291628  1573.024359
#
# Satisfaccion                         Muy Bueno                            \
# Sucursal                                   62           85           267
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  1924.236000  2207.671474  2332.191902
#                  Cobro/Pago        2104.585769  2560.653333  2610.118148
#                  Deposito          1738.388509  2025.384956  1965.381689
# Internacional    Cambio de cheque  1704.684615  2228.274079  2027.230370
#                  Cobro/Pago        2261.479333  2578.015733  2581.548947
#                  Deposito          1837.300500  2010.465685  2102.483889
#
# Satisfaccion
# Sucursal                                   443          586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2235.710351  1883.524190
#                  Cobro/Pago        2644.838989  2269.218108
#                  Deposito          1974.852143  1712.432931
# Internacional    Cambio de cheque  2309.906415  1776.826522
#                  Cobro/Pago        2828.108462  2180.430000
#                  Deposito          2098.884306  1856.835106
#
# [6 rows x 25 columns]

# %%
pd.pivot_table(data_banco,
               index = ['Entidad_Bancaria', 'Transaccion'],
               columns = ['Satisfaccion', 'Sucursal'],
               values = ['Monto_total'],
               aggfunc = ('mean'))
# Out:
#                                    Monto_total                            \
# Satisfaccion                          Muy Malo
# Sucursal                                   62           85           267
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2024.870870  2250.053817  2268.751833
#                  Cobro/Pago        2046.653125  2842.692449  2727.502857
#                  Deposito          1812.322664  2050.882601  1997.838304
# Internacional    Cambio de cheque  1589.861875  2385.933478  2070.034167
#                  Cobro/Pago        2012.905000  2834.870000  2452.595000
#                  Deposito          1772.318958  2034.199859  2102.794286
#
#                                                                           \
# Satisfaccion                                                        Malo
# Sucursal                                   443          586          62
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2320.939545  1880.921220  2007.889074
#                  Cobro/Pago        2207.568750  2146.262353  2085.866912
#                  Deposito          1968.569757  1802.632143  1699.360205
# Internacional    Cambio de cheque  2274.514545  1702.435000  2183.645714
#                  Cobro/Pago        2289.489231  1461.780000  2160.758333
#                  Deposito          1997.837966  1631.284706  1770.014500
#
#                                                                           \
# Satisfaccion
# Sucursal                                   85           267          443
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2234.251757  2191.300331  2236.700370
#                  Cobro/Pago        2669.200085  2631.321975  2956.595106
#                  Deposito          2048.811403  1982.536709  2011.029267
# Internacional    Cambio de cheque  2017.801087  2504.664857  2091.245714
#                  Cobro/Pago        2735.820800  2498.276522  2343.275714
#                  Deposito          2001.742694  2005.566250  1986.784054
#
#                                                 ...                            \
# Satisfaccion                                    ...        Bueno
# Sucursal                                   586  ...          62           85
# Entidad_Bancaria Transaccion                    ...
# Nacional         Cambio de cheque  1847.927368  ...  1809.614035  2328.502648
#                  Cobro/Pago        2150.663684  ...  2092.098636  2689.196237
#                  Deposito          1639.485447  ...  1712.924785  2013.957278
# Internacional    Cambio de cheque  2571.730000  ...  2068.782000  2128.086180
#                  Cobro/Pago        2555.476667  ...  2236.307333  2693.585867
#                  Deposito          1851.356154  ...  1723.520156  2087.520924
#
#                                                                           \
# Satisfaccion
# Sucursal                                   267          443          586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2218.217767  2214.471077  1826.343412
#                  Cobro/Pago        2656.291071  2789.243265  2094.453750
#                  Deposito          1950.198719  1998.891885  1764.654378
# Internacional    Cambio de cheque  2271.415882  2117.297143  1831.948750
#                  Cobro/Pago        3258.440000  2662.936667  1937.088000
#                  Deposito          2163.333333  2134.291628  1573.024359
#
#                                                                           \
# Satisfaccion                         Muy Bueno
# Sucursal                                   62           85           267
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  1924.236000  2207.671474  2332.191902
#                  Cobro/Pago        2104.585769  2560.653333  2610.118148
#                  Deposito          1738.388509  2025.384956  1965.381689
# Internacional    Cambio de cheque  1704.684615  2228.274079  2027.230370
#                  Cobro/Pago        2261.479333  2578.015733  2581.548947
#                  Deposito          1837.300500  2010.465685  2102.483889
#
#
# Satisfaccion
# Sucursal                                   443          586
# Entidad_Bancaria Transaccion
# Nacional         Cambio de cheque  2235.710351  1883.524190
#                  Cobro/Pago        2644.838989  2269.218108
#                  Deposito          1974.852143  1712.432931
# Internacional    Cambio de cheque  2309.906415  1776.826522
#                  Cobro/Pago        2828.108462  2180.430000
#                  Deposito          2098.884306  1856.835106
#
# [6 rows x 25 columns]

# %% [markdown]
# # **5. Unificación**

# %% [markdown]
# ## 5.1 Función/metodo merge
#
# La estructura del merge es:
#
# *merge(dataframe1, dataframe2, how = tipo_union, left_on = 'llave_left', rigth_on = 'llave_right')*
#
# Como método, su estructura es la siguiente:
#
# *dataframe1.merge(dataframe2, how = tipo_union, left_on = 'llave_left', rigth_on = 'llave_right')*

# %%
# Ejemplos de dataframes
df1 = pd.DataFrame({
  'Nombre': ['Jose', 'Claudia', 'Ruben', 'Cecilia', 'Patricia'],
  'Edad' : [30,35,29,39,28],
  'Ciudad': ['Santa Tecla', 'Sonsonate', 'Antiguo Cuscatlan', 'Santa Tecla', 'Soyapango']
    })

df2 = pd.DataFrame({
  'Nombre_2': ['Jose', 'Claudia','Rodrigo'],
  'Unidades' : [130,250,30]
    })

df3 = pd.DataFrame({
  'Nombre': ['Jose', 'Ricardo','Lucas'],
  'Unidades' : [130,250,30]
    })

# %%
# Inner join
# merge(dataframe1, dataframe2, how = tipo_union, left_on = 'llave_left', rigth_on = 'llave_right')
pd.merge(df1, df2, how = 'inner', left_on ='Nombre', right_on = 'Nombre_2')
# Out:
#     Nombre  Edad       Ciudad Nombre_2  Unidades
# 0     Jose    30  Santa Tecla     Jose       130
# 1  Claudia    35    Sonsonate  Claudia       250

# %%
# Inner join
# merge(dataframe1, dataframe2, how = tipo_union, left_on = 'llave_left', rigth_on = 'llave_right')
pd.merge(df1, df2, how = 'inner', left_on ='Nombre', right_on = 'Nombre_2')
# Out:
#     Nombre  Edad       Ciudad Nombre_2  Unidades
# 0     Jose    30  Santa Tecla     Jose       130
# 1  Claudia    35    Sonsonate  Claudia       250

# %%
# Inner join
# merge(dataframe1, dataframe2, how = tipo_union, left_on = 'llave_left', rigth_on = 'llave_right')
pd.merge(df1, df2, how = 'inner', left_on ='Nombre', right_on = 'Nombre_2')
# Out:
#     Nombre  Edad       Ciudad Nombre_2  Unidades
# 0     Jose    30  Santa Tecla     Jose       130
# 1  Claudia    35    Sonsonate  Claudia       250

# %%
# Right join
pd.merge(df1, df2, how = 'right', left_on ='Nombre', right_on = 'Nombre_2')
# Out:
#     Nombre  Edad       Ciudad Nombre_2  Unidades
# 0     Jose  30.0  Santa Tecla     Jose       130
# 1  Claudia  35.0    Sonsonate  Claudia       250
# 2      NaN   NaN          NaN  Rodrigo        30

# %%
# Full join
pd.merge(df1, df2, how = 'outer', left_on ='Nombre', right_on = 'Nombre_2')
# Out:
#      Nombre  Edad             Ciudad Nombre_2  Unidades
# 0      Jose  30.0        Santa Tecla     Jose     130.0
# 1   Claudia  35.0          Sonsonate  Claudia     250.0
# 2     Ruben  29.0  Antiguo Cuscatlan      NaN       NaN
# 3   Cecilia  39.0        Santa Tecla      NaN       NaN
# 4  Patricia  28.0          Soyapango      NaN       NaN
# 5       NaN   NaN                NaN  Rodrigo      30.0

# %% [markdown]
# **Regresando al conjunto de datos**
#
# ¿Qué tipo de unión necesitariamos para nuestro set de datos?

# %%
data_banco.head(1)
# Out:
#    Sucursal  Cajero  ID_Transaccion Transaccion Entidad_Bancaria  \
# 0        62    4820               2  Cobro/Pago    Internacional
#
#    Tiempo_Servicio_seg Satisfaccion   Monto  Interes  Monto_total  \
# 0                311.0    Muy Bueno  2889.3   335.97      3225.27
#
#    Tiempo_Servicio_min  Tiempo_Servicio_min_2
# 0             5.183333               5.183333

# %%
# Join de data_banco con data_cajero
data_banco_consolidado = pd.merge(data_banco, data_cajero, how ='left', left_on = 'Cajero', right_on='Cajero')

# %%
data_banco_consolidado.head()
# Out:
#    Sucursal  Cajero  ID_Transaccion Transaccion Entidad_Bancaria  \
# 0        62    4820               2  Cobro/Pago    Internacional
# 1        62    4820               2  Cobro/Pago         Nacional
# 2        62    4820               2  Cobro/Pago         Nacional
# 3        62    4820               2  Cobro/Pago         Nacional
# 4        62    4820               2  Cobro/Pago         Nacional
#
#    Tiempo_Servicio_seg Satisfaccion    Monto  Interes  Monto_total  \
# 0                311.0    Muy Bueno  2889.30   335.97      3225.27
# 1                156.0         Malo  1670.69   137.23      1807.92
# 2                248.0      Regular  3172.49   143.30      3315.79
# 3                 99.0      Regular  1764.92    42.55      1807.47
# 4                123.0    Muy Bueno  1835.69   199.47      2035.16
#
#    Tiempo_Servicio_min  Tiempo_Servicio_min_2  Edad Sexo Nivel_Formacion  \
# 0             5.183333               5.183333    42    F       Bachiller
# 1             2.600000               2.600000    42    F       Bachiller
# 2             4.133333               4.133333    42    F       Bachiller
# 3             1.650000               1.650000    42    F       Bachiller
# 4             2.050000               2.050000    42    F       Bachiller
#
#    Ingreso
# 0     1995
# 1     1995
# 2     1995
# 3     1995
# 4     1995

# %%
# Cambiar nombres en las variables de un dataframe
data_sucursal.rename(columns = {'Sucursal':'Nombre_Sucursal', 'ID_Sucursal': 'Sucursal'}, inplace = True)

# %%
data_banco_final = pd.merge(data_banco_consolidado, data_sucursal, how = 'left', on = 'Sucursal')

# %%
data_banco_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24299 entries, 0 to 24298
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sucursal               24299 non-null  int64
#  1   Cajero                 24299 non-null  int64
#  2   ID_Transaccion         24299 non-null  int64
#  3   Transaccion            24299 non-null  object
#  4   Entidad_Bancaria       24299 non-null  category
#  5   Tiempo_Servicio_seg    24299 non-null  float64
#  6   Satisfaccion           24299 non-null  category
#  7   Monto                  24299 non-null  float64
#  8   Interes                24299 non-null  float64
#  9   Monto_total            24299 non-null  float64
#  10  Tiempo_Servicio_min    24299 non-null  float64
#  11  Tiempo_Servicio_min_2  24299 non-null  float64
#  12  Edad                   24299 non-null  int64
#  13  Sexo                   24299 non-null  object
#  14  Nivel_Formacion        24299 non-null  object
#  15  Ingreso                24299 non-null  int64
#  16  Nombre_Sucursal        24299 non-null  object
#  17  Nuevo_Sistema          24299 non-null  object
#  18  Plataforma             24299 non-null  object
# dtypes: category(2), float64(6), int64(5), object(6)
# memory usage: 3.4+ MB

# %%
data_banco_final.head(5)
#al final hemos juntado las 3 tablas en una sola
# Out:
#    Sucursal  Cajero  ID_Transaccion Transaccion Entidad_Bancaria  \
# 0        62    4820               2  Cobro/Pago    Internacional
# 1        62    4820               2  Cobro/Pago         Nacional
# 2        62    4820               2  Cobro/Pago         Nacional
# 3        62    4820               2  Cobro/Pago         Nacional
# 4        62    4820               2  Cobro/Pago         Nacional
#
#    Tiempo_Servicio_seg Satisfaccion    Monto  Interes  Monto_total  \
# 0                311.0    Muy Bueno  2889.30   335.97      3225.27
# 1                156.0         Malo  1670.69   137.23      1807.92
# 2                248.0      Regular  3172.49   143.30      3315.79
# 3                 99.0      Regular  1764.92    42.55      1807.47
# 4                123.0    Muy Bueno  1835.69   199.47      2035.16
#
#    Tiempo_Servicio_min  Tiempo_Servicio_min_2  Edad Sexo Nivel_Formacion  \
# 0             5.183333               5.183333    42    F       Bachiller
# 1             2.600000               2.600000    42    F       Bachiller
# 2             4.133333               4.133333    42    F       Bachiller
# 3             1.650000               1.650000    42    F       Bachiller
# 4             2.050000               2.050000    42    F       Bachiller
#
#    Ingreso Nombre_Sucursal Nuevo_Sistema Plataforma
# 0     1995       Sonsonate            No          A
# 1     1995       Sonsonate            No          A
# 2     1995       Sonsonate            No          A
# 3     1995       Sonsonate            No          A
# 4     1995       Sonsonate            No          A
